# %%
# !pip install fundamentus
# !pip install requests-cache
# !pip install yfinance
# !pip install yahoo_fin
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 KB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 4.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 51.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 16.8 MB/s eta 0:00:00
# ...

# %%
import fundamentus
import requests_cache
import requests
import time, logging
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
from yahoo_fin import stock_info
import plotly.graph_objects as go
import numpy as np

# %%
df = fundamentus.get_resultado()

# %%
df.columns 
df
# Out:
# Multiples  cotacao      pl   pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# AALR3        22.29  -19.46  2.46  2.414  0.0000  1.002 -32.14  87.74  -2.59
# ABCB3         0.00    0.00  0.00  0.000  0.0000  0.000   0.00   0.00   0.00
# ABCB4        18.21    5.14  0.79  0.000  0.0767  0.000   0.00   0.00   0.00
# ABEV3        13.32   16.02  2.33  2.655  0.0572  1.477  31.90  13.64 -23.43
# ABYA3         4.91 -214.80  1.76  2.055  0.0000  0.527   1.98  19.96  -2.75
# ...            ...     ...   ...    ...     ...    ...    ...    ...    ...
# WLMM4        24.37    7.82  1.47  0.498  0.0488  1.201   2.85   7.63   3.51
# WMBY3        25.39  -19.30  2.87  0.836  0.0000  0.182   1.20   8.62  -1.50
# WSON33       67.00    8.07  0.98  1.067  0.0000  0.400  13.41   2.42  -0.89
# YDUQ3         7.57  -49.39  0.77  0.518  0.0167  0.236   1.58   4.30  -0.58
# ZAMP3         4.65  -17.27  0.88  0.365  0.0000  0.321   8.72  17.32  -0.83
#
# ...

# %%
df.iloc[[20,21,22], 1]
# Out:
# papel
# AGRO3    21.59
# AGXY3   -22.61
# AHEB3    -5.16
# Name: pl, dtype: float64

# %%
rotulo = df.loc[['ABEV3', 'YDUQ3', 'ASAI3', 'BPAC11', 'SUZB3', 'ITUB4', 'LJQQ3', 'PRIO3']]
rotulo
# Out:
# Multiples  cotacao      pl   pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# ABEV3        13.32   16.02  2.33  2.655  0.0572  1.477  31.90  13.64 -23.43
# YDUQ3         7.57  -49.39  0.77  0.518  0.0167  0.236   1.58   4.30  -0.58
# ASAI3        18.69   20.67  6.47  0.463  0.0087  0.621 -11.27   6.64  -1.12
# BPAC11       20.32    9.94  1.84  0.000  0.0323  0.000   0.00   0.00   0.00
# SUZB3        46.15    3.45  2.25  1.339  0.0517  0.488   2.69   3.28  -0.98
# ITUB4        25.67    8.48  1.55  0.000  0.0391  0.000   0.00   0.00   0.00
# LJQQ3         3.88  258.98  1.40  0.321  0.0000  0.257   0.82   7.13  -1.64
# PRIO3        37.60    9.87  3.61  4.654  0.0000  1.675   3.44   7.68  75.81
#
# Multiples  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# ABEV3       12.59      9.34   0.1947  0.1715  0.1498  0.1452  1.19
# YDUQ3       11.90      5.20   0.1207 -0.0101  0.0669 -0.0157  2.07
# ...

# %%
ax = plt.axes() 
ax.set_facecolor("lightsteelblue") 
rotulo['pl'].plot(figsize=(20,12), color = 'black',ls='dashed', marker='o', markerfacecolor='red', markersize=12)
plt.xlabel('ativo', fontsize = 15)
plt.ylabel('P/L', fontsize = 15)
plt.title('P/L de cada Ativo',
          fontweight ="bold", fontsize = 15)
plt.show()

# %%
ax = plt.axes() 
ax.set_facecolor("lightsteelblue") 
rotulo['pvp'].plot(figsize=(20,12), color = 'black', ls='dashed', marker='o', markerfacecolor='red', markersize=12)
rotulo['psr'].plot(figsize=(20,12), color = 'black',ls='dashed', marker='o', markerfacecolor='red', markersize=12)
plt.xlabel('ativo', fontsize = 15)
plt.ylabel('PVP', fontsize = 15)
plt.title('PVP de cada Ativo', 
          fontweight ="bold", fontsize = 15)
plt.show()

# %%
ax = plt.axes() 
ax.set_facecolor("lightsteelblue") 
rotulo['psr'].plot(figsize=(20,12), color = 'black', ls='dashed', marker='o', markerfacecolor='red', markersize=12)
plt.xlabel('ativo', fontsize = 15)
plt.ylabel('PSR', fontsize = 15)
plt.title('PSR de cada Ativo',
          fontweight ="bold", fontsize = 15)
plt.show()

# %%
ax = plt.axes() 
ax.set_facecolor("lightsteelblue") 
rotulo['roe'].plot(figsize=(20,12), color = 'black', ls='dashed', marker='o', markerfacecolor='red', markersize=12)
rotulo['psr'].plot(figsize=(20,12), color = 'black',ls='dashed', marker='o', markerfacecolor='green', markersize=12)
plt.xlabel('ativo', fontsize = 15)
plt.ylabel('ROE', fontsize = 15)
plt.title('ROE de cada Ativo',
          fontweight ="bold", fontsize = 15)
plt.show()

# %%
ax = plt.axes() 
ax.set_facecolor("lightsteelblue") 
rotulo['pebit'].plot(figsize=(20,12), color = 'black', ls='dashed', marker='o', markerfacecolor='red', markersize=12)
plt.xlabel('ativo', fontsize = 15)
plt.ylabel('PEBIT', fontsize = 15)
plt.title('PEBIT de cada Ativo',
          fontweight ="bold", fontsize = 15)
plt.show()

# %%
ax = plt.axes() 
ax.set_facecolor("lightsteelblue") 
rotulo['cotacao'].plot(figsize=(20,12), color = 'black', ls='dashed', marker='o', markerfacecolor='red', markersize=12)
plt.xlabel('ativo', fontsize = 15)
plt.ylabel('COTAÇÃO', fontsize = 15)
plt.title('COTAÇÃO de cada Ativo',
          fontweight ="bold", fontsize = 15)
plt.show()

# %%
plt.scatter(rotulo['papel'], rotulo['pl'])

# %%
rotulo.to_excel('carteira.xlsx', encoding ='utf-8', index=True)

# %%
## Função que retorna o valor atual de cotação de um ativo.

STK = input ("Enter Share Name : ")
Share = stock_info.get_live_price(STK)
print(Share)
# Out:
# Enter Share Name : AMZN
# 95.79000091552734

# %% [markdown]
# CÓDIGO NÃO MODIFICADO

# %%
df.dtypes
# Out:
# Multiples
# cotacao     float64
# pl          float64
# pvp         float64
# psr         float64
# dy          float64
# pa          float64
# pcg         float64
# pebit       float64
# pacl        float64
# evebit      float64
# evebitda    float64
# mrgebit     float64
# mrgliq      float64
# roic        float64
# roe         float64
# liqc        float64
# liq2m       float64
# patrliq     float64
# divbpatr    float64
# c5y         float64
# dtype: object

# %%
df.describe()
# Out:
# Multiples       cotacao            pl            pvp            psr  \
# count        968.000000    968.000000     968.000000     968.000000
# mean          50.158905     77.249411    1489.351829     142.394062
# std          360.498291   1500.560911   32188.494051    4024.787845
# min            0.000000  -3584.820000    -228.000000     -20.054000
# 25%            4.545000     -0.090000       0.197500       0.062750
# 50%           11.890000      4.475000       1.080000       0.650000
# 75%           28.642500     12.395000       2.102500       1.731000
# max        10081.900000  35552.300000  723708.000000  125160.000000
#
# Multiples          dy          pa           pcg          pebit         pacl  \
# count      968.000000  968.000000    968.000000     968.000000   968.000000
# mean         0.039777    1.972771     13.353957     305.220517    -7.911736
# std          0.207781   23.944637    515.188502    9903.347805   207.425187
# ...

# %% [markdown]
# ## **Screening de ativos**

# %% [markdown]
# E se quisermos trazer papéis de acordo com condições específicas?

# %%
df.pl
# Out:
# papel
# AALR3     -43.06
# ABCB3       0.00
# ABCB4       6.29
# ABEV3      17.76
# ABYA3    -214.80
#            ...
# WLMM3       7.00
# WLMM4       9.50
# WMBY3     -19.30
# WSON33      8.07
# YDUQ3     351.13
# Name: pl, Length: 968, dtype: float64

# %% [markdown]
# Primeira opção de filtro

# %%
filtro1 = df[ (df.pl > 0) & (df.mrgebit > 0.4)]

# %% [markdown]
# Segunda opção de filtro

# %%
filtro2 = df[ (df.pl > 0) & (df.mrgebit > 0.4)& (df.dy > 0.1)]

# %%
filtro1
# Out:
# Multiples  cotacao     pl   pvp     psr      dy     pa    pcg  pebit   pacl  \
# papel
# AFLT3         9.05   4.89  2.18   3.878  0.0471  1.870  11.59   4.74  18.98
# ALSC3        27.75  38.57  2.20  10.717  0.0095  1.202   9.41  19.33  -4.22
# ALSO3        17.58  18.27  0.70   4.449  0.0218  0.412   3.74   8.52  -3.17
# ALUP11       28.45   7.79  1.14   1.757  0.0432  0.307   2.68   2.31  -0.73
# ALUP3         9.43   7.74  1.14   1.747  0.0435  0.305   2.67   2.30  -0.73
# ...            ...    ...   ...     ...     ...    ...    ...    ...    ...
# UCOP4         6.50  18.01  1.30  19.050  0.0000  0.844   5.14  22.70  -8.61
# VALE3        64.50   2.97  1.66   1.243  0.2576  0.698  15.07   2.36  -1.88
# VALE5        33.36   1.54  0.86   0.643  0.0000  0.361   7.79   1.22  -0.97
# WIZS3         8.07  10.25  3.37   1.551  0.0729  0.662  -9.21   3.86  -1.83
# WSON33       67.00   8.07  0.98   1.067  0.0000  0.400  13.41   2.42  -0.89
#
# ...

# %%
filtro1.shape
# Out:
# (63, 20)

# %%
filtro1.sort_values('dy', ascending = False, inplace = True);
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
filtro1.head()
# Out:
# Multiples  cotacao    pl   pvp    psr      dy     pa   pcg  pebit  pacl  \
# papel
# SYNE3         4.56  0.56  0.45  0.299  1.9108  0.157  0.95   0.45 -0.86
# CEBR6        11.37  4.29  0.88  1.992  1.4633  0.619  1.38   4.81  1.46
# CEBR5        10.82  4.08  0.84  1.895  1.3979  0.589  1.31   4.58  1.39
# CEBR3        13.05  4.92  1.01  2.286  1.1590  0.711  1.58   5.52  1.67
# TRPN3         0.71  0.44  0.54  0.263  1.0474  0.399  0.59   0.36  0.59
#
# Multiples  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc      liq2m  \
# papel
# SYNE3        0.84      0.81   0.6570  0.5688  0.4055  0.7985  4.43  2019140.0
# CEBR6        1.85      1.72   0.4140  0.6340  0.2140  0.2058  7.35   256288.0
# CEBR5        1.62      1.50   0.4140  0.6340  0.2140  0.2058  7.35    46760.8
# CEBR3        2.56      2.38   0.4140  0.6340  0.2140  0.2058  7.35    32231.5
# TRPN3       -0.35     -0.35   0.7228  0.5929  5.2301  1.2235  3.61        0.0
#
# Multiples       patrliq  divbpatr     c5y
# ...

# %%
filtro1.index
# Out:
# Index(['SYNE3', 'CEBR6', 'CEBR5', 'CEBR3', 'TRPN3', 'PETR4', 'PETR3', 'EEEL4',
#        'EEEL3', 'VALE3', 'TAEE3', 'TAEE4', 'TAEE11', 'WIZS3', 'TRPL4', 'FESA4',
#        'B3SA3', 'PSSA3', 'JHSF3', 'EGIE3', 'FESA3', 'AFLT3', 'TRPL3', 'ALUP3',
#        'ALUP11', 'ALUP4', 'HBTS5', 'LOGG3', 'MULT3', 'CSAB4', 'ALSO3', 'CSAB3',
#        'CCRO3', 'ALSC3', 'BRML3', 'RECV3', 'TBLE6', 'VALE5', 'TBLE5', 'TIET11',
#        'UCOP4', 'TIET4', 'TIET3', 'SMLS3', 'INEP4', 'SMLE3', 'RIPI4', 'CBMA3',
#        'CESP3', 'CESP4', 'CESP5', 'CESP6', 'CMET4', 'CPFG3', 'CPFG4', 'CPRE3',
#        'HBRE3', 'INEP3', 'MPLU3', 'PRIO3', 'RDCD3', 'RIPI3', 'WSON33'],
#       dtype='object', name='papel')

# %%
filtro1.columns
# Out:
# Index(['cotacao', 'pl', 'pvp', 'psr', 'dy', 'pa', 'pcg', 'pebit', 'pacl',
#        'evebit', 'evebitda', 'mrgebit', 'mrgliq', 'roic', 'roe', 'liqc',
#        'liq2m', 'patrliq', 'divbpatr', 'c5y'],
#       dtype='object', name='Multiples')

# %%
plt.figure(figsize = (20,6));
plt.bar(filtro1.index, filtro1.dy);
plt.xticks(rotation = 45);
plt.title("Ações com P/L maior que 0, margem Ebit maior que 40% e ordenadas por DY");

# %% [markdown]
# Agora vamos analisar o dataframe filtro2

# %%
filtro2.shape
# Out:
# (13, 20)

# %%
filtro2
# Out:
# Multiples  cotacao     pl   pvp    psr      dy     pa    pcg  pebit  pacl  \
# papel
# CEBR3        13.05   4.92  1.01  2.286  1.1590  0.711   1.58   5.52  1.67
# CEBR5        10.82   4.08  0.84  1.895  1.3979  0.589   1.31   4.58  1.39
# CEBR6        11.37   4.29  0.88  1.992  1.4633  0.619   1.38   4.81  1.46
# EEEL3       421.01  33.42  1.87  3.856  0.2999  0.866   3.78   7.72 -7.64
# EEEL4       410.00  32.55  1.82  3.755  0.3387  0.844   3.68   7.52 -7.44
# PETR3        37.17   3.00  1.18  0.853  0.4477  0.483   9.04   1.88 -1.32
# PETR4        33.23   2.68  1.06  0.763  0.5008  0.431   8.08   1.68 -1.18
# SYNE3         4.56   0.56  0.45  0.299  1.9108  0.157   0.95   0.45 -0.86
# TAEE11       41.68   6.89  2.01  4.348  0.1275  0.788   5.37   5.42 -2.02
# TAEE3        13.82   6.85  2.00  4.325  0.1281  0.783   5.34   5.39 -2.01
# TAEE4        13.87   6.88  2.00  4.340  0.1277  0.786   5.36   5.41 -2.01
# TRPN3         0.71   0.44  0.54  0.263  1.0474  0.399   0.59   0.36  0.59
# ...

# %%
filtro2.sort_values('dy', ascending = False, inplace = True);
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
plt.figure(figsize = (20,6));
plt.bar(filtro2.index, filtro2.dy);
plt.xticks(rotation = 45);
plt.title("Ações com P/L maior que 0, margem Ebit maior que 40% e DY acima de 10%, ordenadas por DY");

# %% [markdown]
# Resultado por setor

# %% [markdown]
# https://www.fundamentus.com.br/resultado.php?setor=2

# %%
fundamentus.list_papel_setor(3)
# Out:
# ['BRFS3',
#  'MNPR3',
#  'MRFG3',
#  'JBSS3',
#  'JALL3',
#  'JOPA3',
#  'SMTO3',
#  'CAML3',
#  'JOPA4',
#  'BEEF3',
#  'MDIA3',
#  'BAUH4']

# %% [markdown]
# # **Método Resultado Raw**

# %%
fundamentus.get_resultado_raw()
# Out:
# Multiples  Cotação     P/L  P/VP    PSR  Div.Yield  P/Ativo  P/Cap.Giro  \
# papel
# AALR3        20.10  -43.06  2.08  2.142     0.0000    0.924      -25.58
# ABCB3         0.00    0.00  0.00  0.000     0.0000    0.000        0.00
# ABCB4        19.39    6.29  0.89  0.000     0.0593    0.000        0.00
# ABEV3        15.27   17.76  2.79  3.126     0.0395    1.760       55.40
# ABYA3         4.91 -214.80  1.76  2.055     0.0000    0.527        1.98
# ...            ...     ...   ...    ...        ...      ...         ...
# WLMM3        19.44    7.00  1.23  0.456     0.0455    1.008        2.43
# WLMM4        26.39    9.50  1.66  0.619     0.0369    1.369        3.30
# WMBY3        25.39  -19.30  2.87  0.836     0.0000    0.182        1.20
# WSON33       67.00    8.07  0.98  1.067     0.0000    0.400       13.41
# YDUQ3        12.31  351.13  1.21  0.850     0.0103    0.385        3.56
#
# Multiples  P/EBIT  P/Ativ Circ.Liq  EV/EBIT  EV/EBITDA  Mrg Ebit  Mrg. Líq.  \
# papel
# ...

# %% [markdown]
# # **Método Get Papel**

# %%
fundamentus.get_papel('WEGE3')
# Out:
#        Papel   Tipo       Empresa                    Setor  \
# WEGE3  WEGE3  ON N1  WEG SA ON N1  Máquinas e Equipamentos
#
#                              Subsetor Cotacao Data_ult_cot Min_52_sem  \
# WEGE3  Motores, Compressores e Outros   28.29   2022-08-31      22.68
#
#       Max_52_sem Vol_med_2m  ...  Ativo_Circulante   Div_Bruta Div_Liquida  \
# WEGE3      40.69  211232000  ...       17567000000  2853830000  -218622000
#
#         Patrim_Liq Receita_Liquida_12m    EBIT_12m Lucro_Liquido_12m  \
# WEGE3  13413900000         26752100000  4680650000        3543840000
#
#       Receita_Liquida_3m     EBIT_3m Lucro_Liquido_3m
# WEGE3         7185790000  1246860000        912965000
#
# [1 rows x 48 columns]

# %%
fundamentus.get_detalhes_raw('WEGE3')
# Out:
# [           0                               1                2           3
#  0     ?Papel                           WEGE3         ?Cotação       28.29
#  1      ?Tipo                           ON N1    ?Data últ cot  31/08/2022
#  2   ?Empresa                    WEG SA ON N1      ?Min 52 sem       22.68
#  3     ?Setor         Máquinas e Equipamentos      ?Max 52 sem       40.69
#  4  ?Subsetor  Motores, Compressores e Outros  ?Vol $ méd (2m)   211232000,
#                     0             1                        2           3
#  0  ?Valor de mercado  118742000000  ?Últ balanço processado  30/06/2022
#  1    ?Valor da firma  118524000000              ?Nro. Ações  4197320000,
#               0           1                             2  \
#  0   Oscilações  Oscilações  Indicadores fundamentalistas
#  1          Dia      -0,35%                          ?P/L
#  2          Mês       0,89%                         ?P/VP
#  3      30 dias       0,89%                       ?P/EBIT
# ...

# %%
fundamentus.get_detalhes_papel('WEGE3')
# Out:
#        Papel   Tipo       Empresa                    Setor  \
# WEGE3  WEGE3  ON N1  WEG SA ON N1  Máquinas e Equipamentos
#
#                              Subsetor Cotacao Data_ult_cot Min_52_sem  \
# WEGE3  Motores, Compressores e Outros   28.29   2022-08-31      22.68
#
#       Max_52_sem Vol_med_2m  ...  Ativo_Circulante   Div_Bruta Div_Liquida  \
# WEGE3      40.69  211232000  ...       17567000000  2853830000  -218622000
#
#         Patrim_Liq Receita_Liquida_12m    EBIT_12m Lucro_Liquido_12m  \
# WEGE3  13413900000         26752100000  4680650000        3543840000
#
#       Receita_Liquida_3m     EBIT_3m Lucro_Liquido_3m
# WEGE3         7185790000  1246860000        912965000
#
# [1 rows x 48 columns]

# %%
setor = fundamentus.list_papel_setor(7)

# %%
fundamentus.get_papel(setor)
# Out:
#         Tipo                   Empresa     Setor  \
# ALLD3  ON NM              ALLIED ON NM  Comércio
# AMAR3  ON NM        LOJAS MARISA ON NM  Comércio
# AMER3     ON             AMERICANAS ON  Comércio
# ARZZ3  ON NM           AREZZO CO ON NM  Comércio
# BTTL3     ON             EMBPAR S/A ON  Comércio
# CEAB3  ON NM           CEA MODAS ON NM  Comércio
# CGRA3     ON             GRAZZIOTIN ON  Comércio
# CGRA4     PN             GRAZZIOTIN PN  Comércio
# EPAR3     ON             EMBPAR S/A ON  Comércio
# ESPA3  ON NM         ESPACOLASER ON NM  Comércio
# GUAR3     ON  GUARARAPES CONFECÇÕES ON  Comércio
# LJQQ3  ON NM         QUERO-QUERO ON NM  Comércio
# LLIS3     ON      LE LIS BLANC DEUX ON  Comércio
# LREN3     ON                 RENNER ON  Comércio
# MGLU3  ON NM         MAGAZ LUIZA ON NM  Comércio
# PETZ3  ON NM                PETZ ON NM  Comércio
# SBFG3     ON              GRUPO SBF ON  Comércio
# SLED3     ON        EDITORA SARAIVA ON  Comércio
# ...
